# %% [markdown]
# <a href="https://colab.research.google.com/github/rizthafrrynthii/UTS/blob/main/Kelompok_10_Data_Bangkrut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Memanggil Data Bangkrut**

# %%
data_bangkrut = pd.read_csv ('https://raw.githubusercontent.com/imdwipayana/DATA/65bda7a201579ddaeebb206ceb69908effb8cee1/Dataset%20Final%20Project%202023/Bangkrut/bangkrut.csv')
data_bangkrut
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
data_bangkrut.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
data_bangkrut.tail()
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# ...

# %%
data_bangkrut.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
data_bangkrut.dtypes
# Out:
# Bankrupt?                                                     int64
#  ROA(C) before interest and depreciation before interest    float64
#  ROA(A) before interest and % after tax                     float64
#  ROA(B) before interest and depreciation after tax          float64
#  Operating Gross Margin                                     float64
#                                                              ...
#  Liability to Equity                                        float64
#  Degree of Financial Leverage (DFL)                         float64
#  Interest Coverage Ratio (Interest expense to EBIT)         float64
#  Net Income Flag                                              int64
#  Equity to Liability                                        float64
# Length: 96, dtype: object

# %%
data_bangkrut.isna().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %% [markdown]
# ## **Seleksi Data**

# %%
data_analisis = data_bangkrut [['Bankrupt?', ' Cash flow rate', ' Cash/Total Assets', ' Total debt/Total net worth', ' Cash Flow to Total Assets', ' Net Income to Total Assets']]

# %%
data_analisis = pd.get_dummies(data_analisis)
data_analisis
# Out:
#       Bankrupt?   Cash flow rate   Cash/Total Assets  \
# 0             1         0.458143            0.004094
# 1             1         0.461867            0.014948
# 2             1         0.458521            0.000991
# 3             1         0.465705            0.018851
# 4             1         0.462746            0.014161
# ...         ...              ...                 ...
# 6814          0         0.463734            0.099481
# 6815          0         0.461978            0.080337
# 6816          0         0.472189            0.412885
# 6817          0         0.476123            0.112238
# 6818          0         0.427721            0.238147
#
#        Total debt/Total net worth   Cash Flow to Total Assets  \
# 0                        0.021266                    0.637555
# 1                        0.012502                    0.641100
# 2                        0.021248                    0.642765
# 3                        0.009572                    0.579039
# ...

# %%
data_analisis.head(10)
# Out:
#    Bankrupt?   Cash flow rate   Cash/Total Assets  \
# 0          1         0.458143            0.004094
# 1          1         0.461867            0.014948
# 2          1         0.458521            0.000991
# 3          1         0.465705            0.018851
# 4          1         0.462746            0.014161
# 5          1         0.465861            0.002645
# 6          0         0.461020            0.022989
# 7          0         0.467024            0.014616
# 8          0         0.463142            0.145189
# 9          0         0.470575            0.008773
#
#     Total debt/Total net worth   Cash Flow to Total Assets  \
# 0                     0.021266                    0.637555
# 1                     0.012502                    0.641100
# 2                     0.021248                    0.642765
# 3                     0.009572                    0.579039
# 4                     0.005150                    0.622374
# ...

# %%
data_analisis.isna().sum()
# Out:
# Bankrupt?                      0
#  Cash flow rate                0
#  Cash/Total Assets             0
#  Total debt/Total net worth    0
#  Cash Flow to Total Assets     0
#  Net Income to Total Assets    0
# dtype: int64

# %% [markdown]
# ## **Korelasi Data**

# %%
data_analisis.corr()
# Out:
#                              Bankrupt?   Cash flow rate   Cash/Total Assets  \
# Bankrupt?                     1.000000        -0.072356           -0.100130
#  Cash flow rate              -0.072356         1.000000            0.228027
#  Cash/Total Assets           -0.100130         0.228027            1.000000
#  Total debt/Total net worth   0.012314         0.349639            0.019683
#  Cash Flow to Total Assets   -0.070456         0.224786            0.480174
#  Net Income to Total Assets  -0.315457         0.281309            0.195652
#
#                               Total debt/Total net worth  \
# Bankrupt?                                       0.012314
#  Cash flow rate                                 0.349639
#  Cash/Total Assets                              0.019683
#  Total debt/Total net worth                     1.000000
#  Cash Flow to Total Assets                      0.022285
#  Net Income to Total Assets                    -0.008056
#
# ...

# %%
sns.heatmap(data_analisis.corr())
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(data_analisis.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Split Train Test Data Analisis**

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_analisis[' Total debt/Total net worth']
y = data_analisis[' Cash flow rate']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
# 2969    0.006600
# 6336    0.015212
# 3641    0.014959
# 380     0.005075
# 4886    0.004497
#           ...
# 2244    0.002803
# 5612    0.019368
# 6091    0.003829
# 3466    0.003200
# 1895    0.021508
# Name:  Total debt/Total net worth, Length: 5455, dtype: float64

# %%
X_test
# Out:
# 1686    0.002043
# 6283    0.004533
# 1398    0.003979
# 6545    0.019430
# 4682    0.007576
#           ...
# 3893    0.001665
# 5798    0.004022
# 6498    0.015526
# 4030    0.010063
# 3354    0.005542
# Name:  Total debt/Total net worth, Length: 1364, dtype: float64

# %%
y_train
# Out:
# 2969    0.465345
# 6336    0.461218
# 3641    0.464885
# 380     0.466531
# 4886    0.466873
#           ...
# 2244    0.468037
# 5612    0.459510
# 6091    0.465425
# 3466    0.465459
# 1895    0.459926
# Name:  Cash flow rate, Length: 5455, dtype: float64

# %%
y_test
# Out:
# 1686    0.449482
# 6283    0.470080
# 1398    0.462694
# 6545    0.456169
# 4682    0.467167
#           ...
# 3893    0.479498
# 5798    0.469587
# 6498    0.458007
# 4030    0.465422
# 3354    0.457600
# Name:  Cash flow rate, Length: 1364, dtype: float64
